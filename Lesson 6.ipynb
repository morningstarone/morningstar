# %%
import pandas as pd

x=[2,3,4,5,6]
s=pd.Series(x,index=['a','b','c','d','e'])
print(s)
# Out:
# a    2
# b    3
# c    4
# d    5
# e    6
# dtype: int64

# %%
d={'a':1,'b':2}
pd.Series(d,index={'a','b','h'})
# Out:
# b    2.0
# h    NaN
# a    1.0
# dtype: float64

# %%
web={'day':[2,4,5],'visitor':[200,400,500],'bounce':[5,6,7]}
df=pd.DataFrame(web)

# %%
df.head(n=7)
# Out:
#    day  visitor  bounce
# 0    2      200       5
# 1    4      400       6
# 2    5      500       7

# %%
df.iloc[:2,:2]
# Out:
#    day  visitor
# 0    2      200
# 1    4      400

# %%
df.columns
df.columns.values
# Out:
# array(['day', 'visitor', 'bounce'], dtype=object)

# %%
df.groupby('visitor')

# %%
df.visitor.value_counts()
# Out:
# visitor
# 200    1
# 400    1
# 500    1
# Name: count, dtype: int64

# %%
df1=pd.read_csv('diabetes.csv')
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1.groupby('Pregnancies').mean()
# Out:
#                 Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# Pregnancies
# 0            123.000000      67.153153      22.270270   81.675676  34.290090
# 1            112.748148      67.792593      24.437037   98.674074  31.372593
# 2            110.796117      63.252427      21.601942   85.844660  30.583495
# 3            123.586667      66.586667      20.080000   87.453333  30.425333
# 4            125.117647      70.029412      15.882353   69.441176  32.141176
# 5            118.859649      76.210526      17.385965   57.298246  33.192982
# 6            120.800000      68.420000      17.640000   63.580000  30.290000
# 7            136.444444      70.777778      20.288889   84.466667  32.631111
# 8            131.736842      75.184211      17.315789   92.815789  31.568421
# 9            131.392857      77.892857      20.892857   62.428571  31.707143
# 10           120.916667      70.208333      15.708333   34.791667  30.641667
# ...

# %%
df1.isnull().count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
df1.isna().count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
df=pd.read_csv('matches.csv')
df.head(n=50)
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
df[(df['win_by_runs']==0)].count()
# Out:
# id                 349
# season             349
# city               345
# date               349
# team1              349
# team2              349
# toss_winner        349
# toss_decision      349
# result             349
# dl_applied         349
# winner             346
# win_by_runs        349
# win_by_wickets     349
# player_of_match    346
# venue              349
# umpire1            349
# umpire2            349
# umpire3              0
# dtype: int64

# %%
df.season.value_counts().count()
# Out:
# 10

# %%
for i,j in enumerate(df['win_by_runs']):
    if j==df['win_by_runs'].max():
        print(df['winner'][i])
# Out:
# Mumbai Indians

# %%
for i,j in enumerate(df['win_by_wickets']):
    if j==df['win_by_wickets'].max():
        print(df['winner'][i])
# Out:
# Kolkata Knight Riders
# Kings XI Punjab
# Deccan Chargers
# Delhi Daredevils
# Royal Challengers Bangalore
# Rajasthan Royals
# Mumbai Indians
# Chennai Super Kings
# Royal Challengers Bangalore
# Sunrisers Hyderabad

# %%
# for i,j in enumerate(df['win_by_runs']):
#     if j==df['win_by_runs'].min():
#         print(df['winner'][i])
# Out:
# 636

# %%
import numpy as np
df['win_by_wickets'].replace(0, 20000, inplace=True)
df['win_by_wickets'].min()

for i,j in enumerate(df['win_by_wickets']):
    if j==df['win_by_wickets'].min():
        print(df['winner'][i])
# Out:
# Kolkata Knight Riders

# %%
df['win_by_runs'].replace(0, 200000, inplace=True)
df['win_by_runs'].min()
        
for i,j in enumerate(df['win_by_runs']):
    if j==df['win_by_runs'].min():
        print(df['winner'][i])
# Out:
# Mumbai Indians
# Kings XI Punjab
# Kings XI Punjab
# Delhi Daredevils
# Mumbai Indians
# Chennai Super Kings
# Gujarat Lions
# Royal Challengers Bangalore

# %%
df['season'].value_counts().idxmax()
# Out:
# 2013

# %%
df['winner'].value_counts().idxmax()
# Out:
# 'Mumbai Indians'
